# %% [markdown]
# # SMVA Attack Demonstration
# Single-Model Voting Attack on Self-Consistency

# %%
import sys
sys.path.insert(0, '..')

from src.attacks import SMVAAttack, SMVAConfig

# %%
config = SMVAConfig(
    model_name='gpt-4',
    strategy='sampling_bias',
    num_samples=40
)
attack = SMVAAttack(config)

# %%
result = attack.attack('What is 15% of 80?', target='15')
print(f'Vote Flipped: {result.success}')
