# %% [markdown]
# # MVNA Attack Demonstration
# MCTS Value Network Attack on Tree Search

# %%
import sys
sys.path.insert(0, '..')

from src.attacks import MVNAAttack, MVNAConfig

# %%
config = MVNAConfig(
    mcts_system='mctsr',
    strategy='value_fooling',
    num_simulations=100
)
attack = MVNAAttack(config)

# %%
result = attack.attack('Solve: x^2 - 5x + 6 = 0')
print(f'Search Manipulated: {result.success}')
